# %%
# Nama  : Bonaventura Aldino Senda Seni
# NIM   : 10117122
# Kelas : IF-3

import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
import warnings

# %%
warnings.simplefilter('ignore')

# %%
#membaca dataset dari direktori
df = pd.read_csv("4QualitativeBankcruptcy.csv")
df.head(35)
# Out:
#     Risiko Industri  Risiko Manajemen  Fleksibilitas Keuangan  Kredibilitas  \
# 0                 1                 1                       2             2
# 1                 3                 3                       2             2
# 2                 2                 2                       2             2
# 3                 1                 1                       1             1
# 4                 3                 3                       1             1
# 5                 2                 2                       1             1
# 6                 1                 1                       2             1
# 7                 1                 1                       1             2
# 8                 1                 1                       2             1
# 9                 1                 1                       2             2
# 10                1                 1                       1             1
# ...

# %%
feature_cols = ['Risiko Industri', 'Risiko Manajemen', 'Fleksibilitas Keuangan', 'Kredibilitas','Daya Saing','Risiko Operasi']
X, y = df[feature_cols] , df.Kelas

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size = 0.2)

# %%
ANN = MLPClassifier()
SVM = LinearSVC()
LR = LogisticRegression()

# %%
ANN.fit (X_train, y_train)
ANN.score (X_train, y_train)
# Out:
# 0.935

# %%
SVM.fit (X_train, y_train)
SVM.score (X_train, y_train)
# Out:
# 1.0

# %%
LR.fit (X_train, y_train)
LR.score (X_train, y_train)
# Out:
# 0.995

# %%
ModelBagging = BaggingClassifier()
BC = BaggingClassifier(DecisionTreeClassifier(), max_samples= 0.5, 
                           max_features = 1.0, n_estimators = 20)
BC = BC.fit(X_train, y_train)
y_pred = model.predict(X_test)
print ("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0
